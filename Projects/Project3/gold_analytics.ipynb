# %%
# Gold Layer - Business Analytics Processing

print("Starting Gold Layer - Business Transformation Process...")

# Read Silver Tables

print("Reading Silver layer tables...")

silver_customers_df = spark.table("silver_customers")
print("silver_customers table loaded successfully.")

silver_orders_df = spark.table("silver_orders")
print("silver_orders table loaded successfully.")

silver_products_df = spark.table("silver_products")
print("silver_products table loaded successfully.")

# Perform Business-Level Joins
print("Performing joins to create business analytics dataset...")

gold_retail_df = silver_orders_df.join(silver_customers_df, "customer_id").join(silver_products_df, "product")

print("Business transformation (joins) completed successfully.")

# Print final row count
print(f"Gold Retail Analytics row count: {gold_retail_df.count()}")

# Display Final Output (Preview)
print("Displaying Gold layer dataset preview...")
display(gold_retail_df)

#  Write Final Dataset to Gold Layer
print("Writing final dataset to Gold layer table...")
gold_retail_df.write.format("delta").mode("overwrite").saveAsTable("gold_retail_analytics")
print("gold_retail_analytics table created successfully.")

print("Gold Layer processing completed successfully.")
# Out:
# Starting Gold Layer - Business Transformation Process...
# Reading Silver layer tables...
# silver_customers table loaded successfully.
# silver_orders table loaded successfully.
# silver_products table loaded successfully.
# Performing joins to create business analytics dataset...
# Business transformation (joins) completed successfully.
# Gold Retail Analytics row count: 6
# Displaying Gold layer dataset preview...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product</th><th>customer_id</th><th>order_id</th><th>amount</th><th>name</th><th>email</th><th>city</th><th>product_id</th><th>category</th><th>price</th></tr></thead><tbody><tr><td>Tablet</td><td>3</td><td>103</td><td>15000</td><td>Rahul</td><td>rahul@gmail.com</td><td>Mumbai</td><td>P3</td><td>Electronics</td><td>15000</td></tr><tr><td>Laptop</td><td>4</td><td>108</td><td>80000</td><td>Sneha</td><td>sneha@gmail.com</td><td>Bangalore</td><td>P1</td><td>Electronics</td><td>55000</td></tr><tr><td>Mobile</td><td>2</td><td>102</td><td>20000</td><td>Anita</td><td>anita@gmail.com</td><td>Delhi</td><td>P2</td><td>Electronics</td><td>20000</td></tr><tr><td>Headphones</td><td>1</td><td>104</td><td>3000</td><td>Ravi</td><td>ravi@gmail.com</td><td>Hyderabad</td><td>P4</td><td>Accessories</td><td>3000</td></tr><tr><td>Laptop</td><td>5</td><td>105</td><td>55000</td><td>Arjun</td><td>arjun@gmail.com</td><td>Ahmedabad</td><td>P1</td><td>Electronics</td><td>55000</td></tr><tr><td>Laptop</td><td>1</td><td>101</td><td>55000</td><td>Ravi</td><td>ravi@gmail.com</td><td>Hyderabad</td><td>P1</td><td>Electronics</td><td>55000</td></tr></tbody></table></div>
# Writing final dataset to Gold layer table...
# gold_retail_analytics table created successfully.
# Gold Layer processing completed successfully.

# %%
# %sql
--  Gold Layer - Sales Analytics Query

-- Purpose:
-- Calculate total sales amount for each city

SELECT city, SUM(amount) AS total_sales
FROM gold_retail_analytics
GROUP BY city;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>total_sales</th></tr></thead><tbody><tr><td>Mumbai</td><td>15000</td></tr><tr><td>Bangalore</td><td>80000</td></tr><tr><td>Delhi</td><td>20000</td></tr><tr><td>Hyderabad</td><td>58000</td></tr><tr><td>Ahmedabad</td><td>55000</td></tr></tbody></table></div>
