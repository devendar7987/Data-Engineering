# %%
# Bronze Layer - Raw Data Ingestion

print("Starting Bronze Layer - Raw Ingestion Process...")

# Reading source tables
print("Reading source tables...")

customers_df = spark.table("customers")
print("Customers table loaded successfully.")

orders_df = spark.table("orders")
print("Orders table loaded successfully.")

products_df = spark.table("products")
print("Products table loaded successfully.")

# Display preview

print("Displaying preview of Customers DataFrame")
display(customers_df)

print("Displaying preview of Orders DataFrame")
display(orders_df)

print("Displaying preview of Products DataFrame")
display(products_df)

# Writing to Bronze Layer (Delta Tables)
print("Writing raw data to Bronze layer...")

customers_df.write.format("delta").mode("overwrite").saveAsTable("bronze_customers")
print("bronze_customers table created successfully.")

orders_df.write.format("delta").mode("overwrite").saveAsTable("bronze_orders")
print("bronze_orders table created successfully.")

products_df.write.format("delta").mode("overwrite").saveAsTable("bronze_products")
print("bronze_products table created successfully.")

print("Bronze Layer ingestion completed successfully.")
# Out:
# Starting Bronze Layer - Raw Ingestion Process...
# Reading source tables...
# Customers table loaded successfully.
# Orders table loaded successfully.
# Products table loaded successfully.
# Displaying preview of Customers DataFrame
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>name</th><th>email</th><th>city</th></tr></thead><tbody><tr><td>1</td><td>Ravi</td><td>ravi@gmail.com</td><td>Hyderabad</td></tr><tr><td>2</td><td>Anita</td><td>anita@gmail.com</td><td>Delhi</td></tr><tr><td>3</td><td>Rahul</td><td>rahul@gmail.com</td><td>Mumbai</td></tr><tr><td>4</td><td>Sneha</td><td>sneha@gmail.com</td><td>Bangalore</td></tr><tr><td>5</td><td>Arjun</td><td>arjun@gmail.com</td><td>Ahmedabad</td></tr><tr><td>6</td><td>Kiran</td><td>null</td><td>Chennai</td></tr><tr><td>7</td><td>null</td><td>kiran@gmail.com</td><td>Pune</td></tr><tr><td>3</td><td>Rahul</td><td>rahul@gmail.com</td><td>Mumbai</td></tr><tr><td>8</td><td>Meena</td><td>meena@gmail.com</td><td>null</td></tr></tbody></table></div>
# Displaying preview of Orders DataFrame
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_id</th><th>product</th><th>amount</th></tr></thead><tbody><tr><td>101</td><td>1</td><td>Laptop</td><td>55000</td></tr><tr><td>102</td><td>2</td><td>Mobile</td><td>20000</td></tr><tr><td>103</td><td>3</td><td>Tablet</td><td>15000</td></tr><tr><td>104</td><td>1</td><td>Headphones</td><td>3000</td></tr><tr><td>105</td><td>5</td><td>Laptop</td><td>55000</td></tr><tr><td>106</td><td>6</td><td>Mobile</td><td>null</td></tr><tr><td>107</td><td>null</td><td>Tablet</td><td>15000</td></tr><tr><td>108</td><td>4</td><td>Laptop</td><td>80000</td></tr></tbody></table></div>
# Displaying preview of Products DataFrame
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>product_id</th><th>product</th><th>category</th><th>price</th></tr></thead><tbody><tr><td>P1</td><td>Laptop</td><td>Electronics</td><td>55000</td></tr><tr><td>P2</td><td>Mobile</td><td>Electronics</td><td>20000</td></tr><tr><td>P3</td><td>Tablet</td><td>Electronics</td><td>15000</td></tr><tr><td>P4</td><td>Headphones</td><td>Accessories</td><td>3000</td></tr><tr><td>P2</td><td>Mobile</td><td>Electronics</td><td>20000</td></tr><tr><td>P5</td><td>Camera</td><td>Electronics</td><td>25000</td></tr></tbody></table></div>
# Writing raw data to Bronze layer...
# bronze_customers table created successfully.
# bronze_orders table created successfully.
# bronze_products table created successfully.
# Bronze Layer ingestion completed successfully.
